# %% [markdown]
# # Colab Runtime and GPU Check
#
# ## Setup
# This notebook verifies that your Colab session is ready for GPU lessons.

# %%
# !nvidia-smi

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Device name:', torch.cuda.get_device_name(0))
    print('CUDA version:', torch.version.cuda)

# %% [markdown]
# ## Theory-to-code bridge
# A quick tensor operation confirms that Python and CUDA are connected.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
x = torch.randn(2048, 2048, device=device)
y = torch.randn(2048, 2048, device=device)
z = x @ y
print('Computation finished on', device, 'with shape', z.shape)

# %% [markdown]
# ## Interpretation
# If CUDA is available and matrix multiplication succeeds, your runtime is ready.

# %% [markdown]
# ## Extensions
# - Reconnect runtime and rerun checks
# - Compare different Colab GPU types if available
